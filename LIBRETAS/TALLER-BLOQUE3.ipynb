# %% [markdown]
# # Bloque 3: Preparación del Entorno y Primeros Pasos con Pandas
# En este bloque aprenderás a:
# - Cargar y explorar un archivo CSV.
# - Conocer las estructuras principales de Pandas: *Series* y *DataFrames*.
# - Realizar una inspección inicial de datos reales de biodiversidad.

# %%
! pip install pandas numpy

# %% [markdown]
# 2. Importar librerías

# %%
# Librerías principales
import pandas as pd
import numpy as np

# Configuración opcional para mostrar más filas/columnas
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 10)

# %% [markdown]
# 3. Cargar el conjunto de datos

# %%
# Cargar el archivo CSV (asegúrate de subirlo a Colab o al mismo directorio del Notebook)
# Try different delimiters if needed, e.g., sep=';' or sep='\t'
df = pd.read_csv('db_Dasypus_novemcinctus.csv', sep=',', encoding='utf-8') # Try with comma
# df = pd.read_csv('/content/db_Dasypus_novemcinctus.csv', sep='\t')  # Try with tab


# Verificar las primeras filas
df.head()
# Out:
# /tmp/ipython-input-4165828526.py:3: DtypeWarning: Columns (46) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('db_Dasypus_novemcinctus.csv', sep=',', encoding='utf-8') # Try with comma
#       gbifID                            datasetKey  \
# 0  998689741  0057a720-17c9-4658-971e-9578f3577cf5
# 1  986148719  71e82020-f762-11e1-a439-00145eb45e9a
# 2  923924578  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 3  923924015  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 4  923916591  50c9509d-22c7-4a22-a47d-8c48425ef4a7
#
#                                      occurrenceID   kingdom    phylum  \
# 0                                    FT:RUTM:0003  Animalia  Chordata
# 1                     urn:catalog:OMNH:OCGR:11993  Animalia  Chordata
# 2  http://www.inaturalist.org/observations/759335  Animalia  Chordata
# 3  http://www.inaturalist.org/observations/757410  Animalia  Chordata
# 4  http://www.inaturalist.org/observations/739294  Animalia  Chordata
#
# ...

# %% [markdown]
# *¿Qué tipo de información observas en el dataset? ¿Qué columnas crees que pueden ser útiles para estudiar la distribución de la especie?*

# %% [markdown]
# 4. Inspección inicial de la estructura

# %%
# Número de filas y columnas
df.shape
# Out:
# (46237, 50)

# %%
# Nombres de columnas
df.columns
# Out:
# Index(['gbifID', 'datasetKey', 'occurrenceID', 'kingdom', 'phylum', 'class',
#        'order', 'family', 'genus', 'species', 'infraspecificEpithet',
#        'taxonRank', 'scientificName', 'verbatimScientificName',
#        'verbatimScientificNameAuthorship', 'countryCode', 'locality',
#        'stateProvince', 'occurrenceStatus', 'individualCount',
#        'publishingOrgKey', 'decimalLatitude', 'decimalLongitude',
#        'coordinateUncertaintyInMeters', 'coordinatePrecision', 'elevation',
#        'elevationAccuracy', 'depth', 'depthAccuracy', 'eventDate', 'day',
#        'month', 'year', 'taxonKey', 'speciesKey', 'basisOfRecord',
#        'institutionCode', 'collectionCode', 'catalogNumber', 'recordNumber',
#        'identifiedBy', 'dateIdentified', 'license', 'rightsHolder',
#        'recordedBy', 'typeStatus', 'establishmentMeans', 'lastInterpreted',
#        'mediaType', 'issue'],
#       dtype='object')

# %%
# Información general del DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46237 entries, 0 to 46236
# Data columns (total 50 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   gbifID                            46237 non-null  int64
#  1   datasetKey                        46237 non-null  object
#  2   occurrenceID                      46058 non-null  object
#  3   kingdom                           46237 non-null  object
#  4   phylum                            46237 non-null  object
#  5   class                             46237 non-null  object
#  6   order                             46237 non-null  object
#  7   family                            46237 non-null  object
#  8   genus                             46237 non-null  object
#  9   species                           46237 non-null  object
#  10  infraspecificEpithet              1163 non-null   object
# ...

# %%
# Descripción estadística de las columnas numéricas
df.describe()
# Out:
#              gbifID  individualCount  decimalLatitude  decimalLongitude  \
# count  4.623700e+04     14844.000000     46237.000000      46237.000000
# mean   3.836082e+09         1.452573        16.086007        -82.494216
# std    1.167219e+09         3.757197        16.591560         13.146931
# min    4.277874e+07         1.000000       -49.143170       -123.113521
# 25%    3.051925e+09         1.000000         5.158900        -96.207452
# 50%    4.145417e+09         1.000000        17.540820        -81.339880
# 75%    4.528251e+09         1.000000        30.471619        -73.725000
# max    5.840553e+09       126.000000        50.503887          4.469936
#
#        coordinateUncertaintyInMeters  coordinatePrecision     elevation  \
# count                   2.475200e+04          1128.000000  15179.000000
# mean                    8.705197e+03             0.000170    611.948577
# std                     7.409819e+04             0.000708    655.412002
# ...

# %% [markdown]
# 5. Exploración básica de los datos

# %%
# Mostrar las primeras 10 filas
df.head(10)
# Out:
#       gbifID                            datasetKey  \
# 0  998689741  0057a720-17c9-4658-971e-9578f3577cf5
# 1  986148719  71e82020-f762-11e1-a439-00145eb45e9a
# 2  923924578  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 3  923924015  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 4  923916591  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 5  923915994  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 6  919451765  22a66350-7947-4a49-84a3-39c7c1b0881f
# 7  919451653  22a66350-7947-4a49-84a3-39c7c1b0881f
# 8  919451061  22a66350-7947-4a49-84a3-39c7c1b0881f
# 9  919449155  22a66350-7947-4a49-84a3-39c7c1b0881f
#
#                                      occurrenceID   kingdom    phylum  \
# 0                                    FT:RUTM:0003  Animalia  Chordata
# 1                     urn:catalog:OMNH:OCGR:11993  Animalia  Chordata
# 2  http://www.inaturalist.org/observations/759335  Animalia  Chordata
# 3  http://www.inaturalist.org/observations/757410  Animalia  Chordata
# ...

# %%
# Mostrar las últimas filas
df.tail()
# Out:
#            gbifID                            datasetKey  \
# 46232  1024187881  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 46233  1020746970  83964202-07d9-4a27-8391-975144bcc1da
# 46234  1020746873  83964202-07d9-4a27-8391-975144bcc1da
# 46235  1020746559  83964202-07d9-4a27-8391-975144bcc1da
# 46236  1020746312  83964202-07d9-4a27-8391-975144bcc1da
#
#                                          occurrenceID   kingdom    phylum  \
# 46232  http://www.inaturalist.org/observations/778141  Animalia  Chordata
# 46233                      UIS:UIS-MHN:UIS-MHN-M-0698  Animalia  Chordata
# 46234                      UIS:UIS-MHN:UIS-MHN-M-0598  Animalia  Chordata
# 46235                      UIS:UIS-MHN:UIS-MHN-M-0281  Animalia  Chordata
# 46236                      UIS:UIS-MHN:UIS-MHN-M-0032  Animalia  Chordata
#
#           class      order       family    genus               species  \
# 46232  Mammalia  Cingulata  Dasypodidae  Dasypus  Dasypus novemcinctus
# ...

# %%
# Revisar los tipos de datos de cada columna
df.dtypes
# Out:
# gbifID                 int64
# datasetKey            object
# occurrenceID          object
# kingdom               object
# phylum                object
#                        ...
# typeStatus            object
# establishmentMeans    object
# lastInterpreted       object
# mediaType             object
# issue                 object
# Length: 50, dtype: object

# %% [markdown]
# 6. Identificar valores faltantes

# %%
! pip install missingno

# %%
import missingno as msno

msno.matrix(df.sample(250), label_rotation=90)
# Out:
# <Axes: >

# %%
# Contar valores faltantes por columna
print(df.isna().sum())
# Out:
# gbifID                    0
# datasetKey                0
# occurrenceID            179
# kingdom                   0
# phylum                    0
#                       ...
# typeStatus            45921
# establishmentMeans    44392
# lastInterpreted           0
# mediaType             21782
# issue                 14513
# Length: 50, dtype: int64

# %%
# Porcentaje de valores faltantes
(df.isna().sum() / len(df) * 100).round(2)
# Out:
# gbifID                 0.00
# datasetKey             0.00
# occurrenceID           0.39
# kingdom                0.00
# phylum                 0.00
#                       ...
# typeStatus            99.32
# establishmentMeans    96.01
# lastInterpreted        0.00
# mediaType             47.11
# issue                 31.39
# Length: 50, dtype: float64

# %% [markdown]
# 7. Ejercicios guiados

# %% [markdown]
# Filtrar las columnas más relevantes para análisis biológico:

# %%
df.columns
# Out:
# Index(['gbifID', 'datasetKey', 'occurrenceID', 'kingdom', 'phylum', 'class',
#        'order', 'family', 'genus', 'species', 'infraspecificEpithet',
#        'taxonRank', 'scientificName', 'verbatimScientificName',
#        'verbatimScientificNameAuthorship', 'countryCode', 'locality',
#        'stateProvince', 'occurrenceStatus', 'individualCount',
#        'publishingOrgKey', 'decimalLatitude', 'decimalLongitude',
#        'coordinateUncertaintyInMeters', 'coordinatePrecision', 'elevation',
#        'elevationAccuracy', 'depth', 'depthAccuracy', 'eventDate', 'day',
#        'month', 'year', 'taxonKey', 'speciesKey', 'basisOfRecord',
#        'institutionCode', 'collectionCode', 'catalogNumber', 'recordNumber',
#        'identifiedBy', 'dateIdentified', 'license', 'rightsHolder',
#        'recordedBy', 'typeStatus', 'establishmentMeans', 'lastInterpreted',
#        'mediaType', 'issue'],
#       dtype='object')

# %%
columnas_relevantes = ['scientificName', 'decimalLatitude', 'decimalLongitude', 'year', 'basisOfRecord', 'countryCode', 'stateProvince']
df_relevante = df[columnas_relevantes]
df_relevante.head()
# Out:
#                         scientificName  decimalLatitude  decimalLongitude  \
# 0  Dasypus novemcinctus Linnaeus, 1758         4.590363        -76.112254
# 1  Dasypus novemcinctus Linnaeus, 1758        35.056845        -89.423007
# 2  Dasypus novemcinctus Linnaeus, 1758        31.950620        -99.947504
# 3  Dasypus novemcinctus Linnaeus, 1758        29.717738        -98.437534
# 4  Dasypus novemcinctus Linnaeus, 1758        30.267153        -97.743061
#
#      year       basisOfRecord countryCode    stateProvince
# 0     NaN   HUMAN_OBSERVATION          CO  Valle del Cauca
# 1  1995.0  PRESERVED_SPECIMEN          US        Tennessee
# 2  2014.0   HUMAN_OBSERVATION          US            Texas
# 3  2014.0   HUMAN_OBSERVATION          US            Texas
# 4  2014.0   HUMAN_OBSERVATION          US            Texas

# %%
df_relevante.columns
# Out:
# Index(['scientificName', 'decimalLatitude', 'decimalLongitude', 'year',
#        'basisOfRecord', 'countryCode', 'stateProvince'],
#       dtype='object')

# %% [markdown]
# Contar registros por país:

# %%
df_relevante['countryCode'].value_counts()
# Out:
# countryCode
# US    21281
# CO    15259
# EC     2357
# MX     2100
# BR     2009
#       ...
# NI       37
# GY       19
# GD        3
# BE        1
# CA        1
# Name: count, Length: 25, dtype: int64

# %%
# Para guardar el nuevo dataframe
df_relevante.to_csv('df_limpio.csv', index=False)

# %% [markdown]
# Contar registros por año:

# %%
df_relevante['year'].value_counts().sort_index()
# Out:
# year
# 1843.0       1
# 1855.0       1
# 1869.0       1
# 1881.0       1
# 1882.0       2
#           ...
# 2021.0    6283
# 2022.0    5633
# 2023.0    4119
# 2024.0    4221
# 2025.0    3558
# Name: count, Length: 124, dtype: int64

# %% [markdown]
# Verificar duplicados:

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_relevante.shape
# Out:
# (46237, 7)

# %%
df_relevante["decimalLatitude"].isna().sum()
# Out:
# np.int64(0)

# %% [markdown]
# **Ejercicio**
# 1. ¿Cuántos registros totales hay en el dataset?
# 2. ¿Cuántos registros tienen coordenadas completas (latitud y longitud)?
# 3. ¿Cuál es el año más antiguo y el más reciente registrado?
# 4. ¿Cuántos países diferentes están representados en los datos?
#
# *Tip:*
#
# ```
# .dropna(subset=['decimalLatitude', 'decimalLongitude'])
# ```
#  *Usa el codigo anterior para contar registros con coordenadas.*

# %% [markdown]
# 9. Conclusión del bloque

# %% [markdown]
# En este bloque aprendiste a:
# ✅ Cargar datos CSV con Pandas.
# ✅ Inspeccionar su estructura y detectar problemas comunes (NaN, duplicados, tipos de datos).
# ✅ Realizar una exploración inicial que servirá como base para la limpieza y análisis en el siguiente bloque.

# %% [markdown]
# # **EJERCICIOS**

# %% [markdown]
# 1. Carga y revisión inicial

# %%
import pandas as pd

# Subir el nuevo archivo CSV desde GBIF
df = pd.read_csv('tu_dataset.csv')

# Revisión inicial
print("Filas y columnas:", df.shape)
display(df.head())

# Información general
df.info()

# Columnas disponibles
df.columns

# %% [markdown]
# ¿Cuántos registros tiene tu dataset?
#
# ¿Qué campos son los más relevantes para tu especie o grupo?
#
# ¿El dataset tiene coordenadas (latitud/longitud)?

# %% [markdown]
# 2. Análisis básico de calidad

# %%
# Revisar valores faltantes
df.isna().sum().sort_values(ascending=False).head(10)

# Verificar duplicados
print("Registros duplicados:", df.duplicated().sum())

# Revisar rangos de coordenadas
print(df['decimalLatitude'].min(), df['decimalLatitude'].max())
print(df['decimalLongitude'].min(), df['decimalLongitude'].max())

# %% [markdown]
# ¿Existen coordenadas fuera del rango válido (-90 a 90, -180 a 180)?
#
# ¿Podrías filtrar solo registros con coordenadas válidas?

# %%
df_valid = df[
    (df['decimalLatitude'].between(-90, 90)) &
    (df['decimalLongitude'].between(-180, 180))
]

# %% [markdown]
# 3. Estadísticas descriptivas simples

# %%
# Registros por año
df['year'].value_counts().sort_index().plot(kind='bar', figsize=(10,4), title='Registros por año')

# Registros por país
df['country'].value_counts().head(10)

# %% [markdown]
# ¿Cuáles son los 5 países con más registros?
#
# ¿El número de registros ha aumentado o disminuido con el tiempo?

# %% [markdown]
# 4. Subconjuntos de interés

# %%
# Filtrar registros recientes
df_2000 = df[df['year'] >= 2000]

# Filtrar por país o estado
df_mexico = df[df['country'] == 'Mexico']

# Filtrar por tipo de registro
df_observaciones = df[df['basisOfRecord'] == 'HUMAN_OBSERVATION']

# %% [markdown]
# ¿Qué porcentaje de tus registros son observaciones humanas?
#
# ¿Cuál es la proporción de registros antiguos vs. recientes?

# %% [markdown]
# 5. Exploración de variabilidad taxonómica

# %%
df['scientificName'].value_counts().head(10)

# %% [markdown]
# ¿El dataset incluye solo una especie o varias?
#
# Si hay varias, ¿cuál tiene más registros?
